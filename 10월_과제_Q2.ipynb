# %% [markdown]
# ## 2) 서울시 지하철 호선별 역별 시간대별 승하차 인원 정보 시트 데이터와 서울특별시 코로나19 백신 예방접종 현황 시트 데이터를 사용하여
# 2021년 1월부터 2021년 9월까지의  2차 누적접종률을 월 단위로 막대그래프로 출력하고(데이터가 없을 경우 0 표기), 호선별 월 이용 인원을 꺾은선 그래프로 함께 출력하시오.

# %%
# Pandas 라이브러리 불러오기
import pandas as pd

# numpy 라이브러리 불러오기
import numpy as np

# matplotlib 라이브러리 불러오기
from matplotlib import pyplot as plt

# %%
# 2번 solution
# 2021년 1월부터 2021년 9월까지의 2차 누적접종률을 월 단위로 막대그래프로 출력하고(데이터가 없을 겨웅 0 표기), 
# 호선별 월 이용 인원을 꺾은선 그래프로 함게 출력하시오.

df2 = pd.read_excel('전공_파이썬데이터분석과제_이름_ID.xlsx', sheet_name = 4)

# %%
df2
# Out:
#             접종일    접종대상자  당일 1차접종자 수  1차접종 누계  1차접종률(%)  당일 2차접종자 수  2차접종 누계  \
# 0    2021.10.10  9505868         330  7480597      78.7        3236  5673019
# 1    2021.10.09  9505868        1373  7480266      78.7       15337  5669744
# 2    2021.10.08  9505868        6847  7479069      78.6      200186  5654619
# 3    2021.10.07  9505868        5982  7471415      78.6      138375  5353493
# 4    2021.10.06  9505868        6247  7464613      78.5       95261  5314014
# ..          ...      ...         ...      ...       ...         ...      ...
# 168  2021.04.25  1023346       23323   350631      34.2        3411    18513
# 169  2021.04.24  1023346         200   350427      34.2           0    18513
# 170  2021.04.23  1027740       10195   345764      33.6         119    18376
# 171  2021.04.22  1023538       27074   317386      31.0        2479    15901
# 172  2021.04.21  1019322       22501   291857      28.6        2358    13543
#
#      2차접종률(%)
# 0        59.6
# ...

# %%
condition = (df2['접종일'] >= "2021.01.01") & (df2['접종일'] <= "2021.09.31") # 조건식 작성

# %%
df2 = df2[condition]
df2
# Out:
#             접종일    접종대상자  당일 1차접종자 수  1차접종 누계  1차접종률(%)  당일 2차접종자 수  2차접종 누계  \
# 10   2021.09.30  9505868       41307  7382559      77.7      156636  4786032
# 11   2021.09.29  9505868       67946  7314953      77.0      104742  4681112
# 12   2021.09.28  9505868       40336  7274915      76.5      105746  4575154
# 13   2021.09.27  9505868       47035  7228337      76.0      132787  4442337
# 14   2021.09.26  9505868       78584  7149465      75.2      139274  4302483
# ..          ...      ...         ...      ...       ...         ...      ...
# 168  2021.04.25  1023346       23323   350631      34.2        3411    18513
# 169  2021.04.24  1023346         200   350427      34.2           0    18513
# 170  2021.04.23  1027740       10195   345764      33.6         119    18376
# 171  2021.04.22  1023538       27074   317386      31.0        2479    15901
# 172  2021.04.21  1019322       22501   291857      28.6        2358    13543
#
#      2차접종률(%)
# 10       50.3
# ...

# %%
df3 = pd.read_excel('전공_파이썬데이터분석과제_이름_ID.xlsx', sheet_name = 3)
df3
# Out:
#           사용월  호선명 지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  \
# 0      202109  1호선  동대문           504            11         10220
# 1      202109  1호선  동묘앞            91             2          2562
# 2      202109  1호선  서울역           540            16          7420
# 3      202109  1호선   시청            25             0          1677
# 4      202109  1호선  신설동           267            10          6634
# ...       ...  ...  ...           ...           ...           ...
# 47154  201501  중앙선  운길산             0             0           177
# 47155  201501  중앙선   원덕             1             0           292
# 47156  201501  중앙선   중랑            14             1          4929
# 47157  201501  중앙선   팔당             0             0           161
# 47158  201501  중앙선   회기           436             3         10929
#
#        05시-06시 하차인원  06시-07시 승차인원  06시-07시 하차인원  07시-08시 승차인원  ...  \
# 0              1863          8046          5696         12719  ...
# ...

# %%
condition = (df3['사용월'] >= 202101) & (df3['사용월'] <= 202109) # 조건식 작성

# %%
df3 = df3[condition]
df3
# Out:
#          사용월  호선명 지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  \
# 0     202109  1호선  동대문           504            11         10220
# 1     202109  1호선  동묘앞            91             2          2562
# 2     202109  1호선  서울역           540            16          7420
# 3     202109  1호선   시청            25             0          1677
# 4     202109  1호선  신설동           267            10          6634
# ...      ...  ...  ...           ...           ...           ...
# 5455  202101  중앙선   원덕            15             0           228
# 5456  202101  중앙선   중랑            75             1          4549
# 5457  202101  중앙선   지평             0             0             0
# 5458  202101  중앙선   팔당             0             0           110
# 5459  202101  중앙선   회기           467             5          7992
#
#       05시-06시 하차인원  06시-07시 승차인원  06시-07시 하차인원  07시-08시 승차인원  ...  \
# 0             1863          8046          5696         12719  ...
# ...

# %% [markdown]
# #### 누적 접종률 월단위 막대그래프

# %%
# calendar 라이브러리 불러오기
import calendar

# x축
x_data = ["21.01", "21.02", "21.03", "21.04", "21.05", "21.06", "21.07", "21.08", "21.09"]

# y축
y_data = []
for i in range(1,10):
    day = calendar.monthrange(2021,i)[1]
    condition = (df2['접종일'] == "2021." + "0" + str(i)+ "." + str(day)) # 조건식 작성
    if(len(df2[condition])==0):
        y_data.append(0)
    else:
        y_data.append(df2[condition]['2차접종률(%)'])
        
x_data2 = [202101, 202102, 202103, 202104, 202105, 202106, 202107, 202108, 202109]

plt.ylim([0,100])

plt.bar(x_data2, y_data)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# #### 호선별 월 이용 인원을 꺾은선 그래프

# %%
df_temp = df3.drop(['작업일자','사용월'], axis=1)
df3['총이용인원'] = df_temp.sum(axis=1)
df3
# Out:
#          사용월  호선명 지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  \
# 0     202109  1호선  동대문           504            11         10220
# 1     202109  1호선  동묘앞            91             2          2562
# 2     202109  1호선  서울역           540            16          7420
# 3     202109  1호선   시청            25             0          1677
# 4     202109  1호선  신설동           267            10          6634
# ...      ...  ...  ...           ...           ...           ...
# 5455  202101  중앙선   원덕            15             0           228
# 5456  202101  중앙선   중랑            75             1          4549
# 5457  202101  중앙선   지평             0             0             0
# 5458  202101  중앙선   팔당             0             0           110
# 5459  202101  중앙선   회기           467             5          7992
#
#       05시-06시 하차인원  06시-07시 승차인원  06시-07시 하차인원  07시-08시 승차인원  ...  \
# 0             1863          8046          5696         12719  ...
# ...

# %%
sorted_series3 = df3.groupby(['호선명','사용월'])['총이용인원'].sum()
sorted_df3 = pd.DataFrame(sorted_series3, columns=['총이용인원'])
pd.DataFrame(sorted_df3.loc['1호선', '총이용인원'])
# Out:
#            총이용인원
# 사용월
# 202101   8982246
# 202102   9221920
# 202103  11501542
# 202104  11372871
# 202105  11195148
# 202106  11494793
# 202107  10136973
# 202108   9740681
# 202109   9980235

# %%
from matplotlib import rc
import seaborn as sns
# %matplotlib inline

# mac용 한글 폰트
# rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

table = sorted_df3.pivot_table(values='총이용인원', index='사용월', columns='호선명', fill_value=0)
table
# Out:
# 호선명          1호선       2호선       3호선       4호선       5호선       6호선       7호선  \
# 사용월
# 202101   8982246  56303019  21283426  20112122  25947793  13442450  29650569
# 202102   9221920  56931162  21650716  20233006  25972275  13563967  28947276
# 202103  11501542  70999030  26695227  25378237  32892794  16967155  36012370
# 202104  11372871  69677619  26346589  24979856  33044136  16802817  35836971
# 202105  11195148  68236496  25859850  24581762  31967876  16528382  34797189
# 202106  11494793  70925213  26594741  25136678  32968818  16945658  35925120
# 202107  10136973  62508425  23696540  22495138  29486275  15125164  32602325
# 202108   9740681  59877347  22745734  21465689  28195756  14534039  30966482
# 202109   9980235  59674070  23163816  21886354  28403895  14825732  31165245
#
# 호선명         8호선       9호선  9호선2~3단계  ...      경춘선  공항철도 1호선      과천선  \
# 사용월                                  ...
# 202101  8340897  11165664   3809017  ...  1465364   3645026  4026415
# ...

# %%
# x축 생성
x_data2 = ["","202101","202102","202103","202104","202105","202106","202107","202108","202109"]

ax = table.plot(figsize=(10,10))
ax.set_xticklabels(x_data2)
# Out:
# <ipython-input-43-8604ed244104>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x_data2)
# [Text(202100.0, 0, ''),
#  Text(202101.0, 0, '202101'),
#  Text(202102.0, 0, '202102'),
#  Text(202103.0, 0, '202103'),
#  Text(202104.0, 0, '202104'),
#  Text(202105.0, 0, '202105'),
#  Text(202106.0, 0, '202106'),
#  Text(202107.0, 0, '202107'),
#  Text(202108.0, 0, '202108'),
#  Text(202109.0, 0, '202109'),
#  Text(202110.0, 0, '')]
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50857 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50900 missing from current font.
# ...

# %%
plt.rcParams['figure.figsize']=(36,24)
fig, ax1 = plt.subplots()

ax1.plot(table)
x_data2 = [202101,202102,202103,202104,202105,202106,202107,202108,202109]

# ax1 = table.plot()
ax1.set_xticklabels(x_data2)

ax1.tick_params(axis='both', direction='in')
# x_data2 = ["202101","202102","202103","202104","202105","202106","202107","202108","202109"]

ax2 = ax1.twinx()
ax2.bar(x_data2, y_data)
ax2.tick_params(axis='y', direction='in')
# Out:
# <ipython-input-48-55c311d577d0>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(x_data2)
